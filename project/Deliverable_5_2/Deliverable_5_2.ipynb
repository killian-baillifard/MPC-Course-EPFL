# %%
# Get parent directory and add to sys.path
import os; import sys
import numpy as np
parent_dir = os.path.dirname(os.getcwd())
sys.path.append(parent_dir)

# Require ipympl
# %matplotlib widget

# %%
# MPC import
from OffsetFreeLinearMPC.MPCVelControl import MPCVelControl

from src.rocket import Rocket
from src.vel_rocket_vis import RocketVis, plot_static_states_inputs

rocket_obj_path = os.path.join(parent_dir, "Cartoon_rocket.obj")
rocket_params_path = os.path.join(parent_dir, "rocket.yaml")

# %%
Ts = 0.05
sim_time = 20
H = 3.0
x0 = np.array([0, 0, 0, 0, 0, 0, 5, 5, 10, 0, 0, 1])  # initial state
x_target = np.zeros((12,))

rocket = Rocket(Ts=Ts, model_params_filepath=rocket_params_path)
mpc = MPCVelControl().new_controller(rocket, Ts, H)

# Static mass change and zero fuel rate
rocket.mass = 2.0
rocket.fuel_rate = 0.1
t_cl, x_cl, u_cl, t_ol, x_ol, u_ol, ref = rocket.simulate_control(mpc, sim_time, H, x0, x_target=x_target, method='nonlinear')
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# Simulating time 0.00: Fuel left: 1.00 kg,
# Simulating time 0.05: Fuel left: 1.00 kg,
# Simulating time 0.10: Fuel left: 0.99 kg,
# Simulating time 0.15: Fuel left: 0.99 kg,
# Simulating time 0.20: Fuel left: 0.99 kg,
# Simulating time 0.25: Fuel left: 0.99 kg,
# Simulating time 0.30: Fuel left: 0.99 kg,
# Simulating time 0.35: Fuel left: 0.98 kg,
# Simulating time 0.40:
#  State beta violation: -0.19 < -0.17,
#  State alpha violation: 0.19 > 0.17, Fuel left: 0.98 kg,
# Simulating time 0.45:
#  State beta violation: -0.20 < -0.17,
#  State alpha violation: 0.21 > 0.17, Fuel left: 0.98 kg,
# Simulating time 0.50:
#  State beta violation: -0.22 < -0.17,
#  State alpha violation: 0.22 > 0.17, Fuel left: 0.98 kg,
# Simulating time 0.55:
#  State beta violation: -0.23 < -0.17,
#  State alpha violation: 0.23 > 0.17, Fuel left: 0.98 kg,
# Simulating time 0.60:
#  State beta violation: -0.24 < -0.17,
#  State alpha violation: 0.24 > 0.17, Fuel left: 0.97 kg,
# Simulating time 0.65:
#  State beta violation: -0.24 < -0.17,
#  State alpha violation: 0.25 > 0.17, Fuel left: 0.97 kg,
# Simulating time 0.70:
#  State beta violation: -0.25 < -0.17,
#  State alpha violation: 0.25 > 0.17, Fuel left: 0.97 kg,
# Simulating time 0.75:
#  State beta violation: -0.25 < -0.17,
#  State alpha violation: 0.26 > 0.17, Fuel left: 0.97 kg,
# Simulating time 0.80:
#  State beta violation: -0.25 < -0.17,
#  State alpha violation: 0.26 > 0.17, Fuel left: 0.97 kg,
# Simulating time 0.85:
#  State beta violation: -0.26 < -0.17,
#  State alpha violation: 0.26 > 0.17, Fuel left: 0.96 kg,
# Simulating time 0.90:
#  State beta violation: -0.26 < -0.17,
#  State alpha violation: 0.26 > 0.17, Fuel left: 0.96 kg,
# Simulating time 0.95:
#  State beta violation: -0.26 < -0.17,
#  State alpha violation: 0.26 > 0.17, Fuel left: 0.96 kg,
# Simulating time 1.00:
#  State beta violation: -0.26 < -0.17,
#  State alpha violation: 0.26 > 0.17, Fuel left: 0.96 kg,
# Simulating time 1.05:
#  State beta violation: -0.25 < -0.17,
#  State alpha violation: 0.26 > 0.17, Fuel left: 0.96 kg,
# Simulating time 1.10:
#  State beta violation: -0.25 < -0.17,
#  State alpha violation: 0.25 > 0.17, Fuel left: 0.95 kg,
# Simulating time 1.15:
#  State beta violation: -0.25 < -0.17,
#  State alpha violation: 0.25 > 0.17, Fuel left: 0.95 kg,
# Simulating time 1.20:
#  State beta violation: -0.25 < -0.17,
#  State alpha violation: 0.25 > 0.17, Fuel left: 0.95 kg,
# Simulating time 1.25:
#  State beta violation: -0.24 < -0.17,
#  State alpha violation: 0.24 > 0.17, Fuel left: 0.95 kg,
# Simulating time 1.30:
#  State beta violation: -0.24 < -0.17,
#  State alpha violation: 0.24 > 0.17, Fuel left: 0.95 kg,
# Simulating time 1.35:
#  State beta violation: -0.24 < -0.17,
#  State alpha violation: 0.24 > 0.17, Fuel left: 0.94 kg,
# Simulating time 1.40:
#  State beta violation: -0.23 < -0.17,
#  State alpha violation: 0.23 > 0.17, Fuel left: 0.94 kg,
# Simulating time 1.45:
#  State beta violation: -0.23 < -0.17,
#  State alpha violation: 0.23 > 0.17, Fuel left: 0.94 kg,
# Simulating time 1.50:
#  State beta violation: -0.23 < -0.17,
#  State alpha violation: 0.23 > 0.17, Fuel left: 0.94 kg,
# Simulating time 1.55:
#  State beta violation: -0.22 < -0.17,
#  State alpha violation: 0.22 > 0.17, Fuel left: 0.94 kg,
# Simulating time 1.60:
#  State beta violation: -0.22 < -0.17,
#  State alpha violation: 0.22 > 0.17, Fuel left: 0.93 kg,
# Simulating time 1.65:
#  State beta violation: -0.21 < -0.17,
#  State alpha violation: 0.22 > 0.17, Fuel left: 0.93 kg,
# Simulating time 1.70:
#  State beta violation: -0.21 < -0.17,
#  State alpha violation: 0.21 > 0.17, Fuel left: 0.93 kg,
# Simulating time 1.75:
#  State beta violation: -0.21 < -0.17,
#  State alpha violation: 0.21 > 0.17, Fuel left: 0.93 kg,
# Simulating time 1.80:
#  State beta violation: -0.20 < -0.17,
#  State alpha violation: 0.20 > 0.17, Fuel left: 0.93 kg,
# Simulating time 1.85:
#  State beta violation: -0.20 < -0.17,
#  State alpha violation: 0.20 > 0.17, Fuel left: 0.92 kg,
# Simulating time 1.90:
#  State beta violation: -0.19 < -0.17,
#  State alpha violation: 0.20 > 0.17, Fuel left: 0.92 kg,
# Simulating time 1.95:
#  State beta violation: -0.19 < -0.17,
#  State alpha violation: 0.19 > 0.17, Fuel left: 0.92 kg,
# Simulating time 2.00:
#  State beta violation: -0.19 < -0.17,
#  State alpha violation: 0.19 > 0.17, Fuel left: 0.92 kg,
# Simulating time 2.05:
#  State beta violation: -0.18 < -0.17,
#  State alpha violation: 0.19 > 0.17, Fuel left: 0.92 kg,
# Simulating time 2.10:
#  State beta violation: -0.18 < -0.17,
#  State alpha violation: 0.18 > 0.17, Fuel left: 0.91 kg,
# Simulating time 2.15:
#  State beta violation: -0.18 < -0.17,
#  State alpha violation: 0.18 > 0.17, Fuel left: 0.91 kg,
# Simulating time 2.20: Fuel left: 0.91 kg,
# Simulating time 2.25: Fuel left: 0.91 kg,
# Simulating time 2.30: Fuel left: 0.90 kg,
# Simulating time 2.35: Fuel left: 0.90 kg,
# Simulating time 2.40: Fuel left: 0.90 kg,
# Simulating time 2.45: Fuel left: 0.90 kg,
# Simulating time 2.50: Fuel left: 0.89 kg,
# Simulating time 2.55: Fuel left: 0.89 kg,
# Simulating time 2.60: Fuel left: 0.89 kg,
# Simulating time 2.65: Fuel left: 0.88 kg,
# Simulating time 2.70: Fuel left: 0.88 kg,
# Simulating time 2.75: Fuel left: 0.88 kg,
# Simulating time 2.80: Fuel left: 0.88 kg,
# Simulating time 2.85: Fuel left: 0.87 kg,
# Simulating time 2.90: Fuel left: 0.87 kg,
# Simulating time 2.95: Fuel left: 0.87 kg,
# Simulating time 3.00: Fuel left: 0.86 kg,
# Simulating time 3.05: Fuel left: 0.86 kg,
# Simulating time 3.10: Fuel left: 0.86 kg,
# Simulating time 3.15: Fuel left: 0.85 kg,
# Simulating time 3.20: Fuel left: 0.85 kg,
# Simulating time 3.25: Fuel left: 0.85 kg,
# Simulating time 3.30: Fuel left: 0.85 kg,
# Simulating time 3.35: Fuel left: 0.84 kg,
# Simulating time 3.40: Fuel left: 0.84 kg,
# Simulating time 3.45: Fuel left: 0.84 kg,
# Simulating time 3.50: Fuel left: 0.83 kg,
# Simulating time 3.55: Fuel left: 0.83 kg,
# Simulating time 3.60: Fuel left: 0.83 kg,
# Simulating time 3.65: Fuel left: 0.82 kg,
# Simulating time 3.70: Fuel left: 0.82 kg,
# Simulating time 3.75: Fuel left: 0.82 kg,
# Simulating time 3.80: Fuel left: 0.81 kg,
# Simulating time 3.85: Fuel left: 0.81 kg,
# Simulating time 3.90: Fuel left: 0.81 kg,
# Simulating time 3.95: Fuel left: 0.81 kg,
# Simulating time 4.00: Fuel left: 0.80 kg,
# Simulating time 4.05: Fuel left: 0.80 kg,
# Simulating time 4.10: Fuel left: 0.80 kg,
# Simulating time 4.15: Fuel left: 0.79 kg,
# Simulating time 4.20: Fuel left: 0.79 kg,
# Simulating time 4.25: Fuel left: 0.79 kg,
# Simulating time 4.30: Fuel left: 0.78 kg,
# Simulating time 4.35: Fuel left: 0.78 kg,
# Simulating time 4.40: Fuel left: 0.78 kg,
# Simulating time 4.45: Fuel left: 0.78 kg,
# Simulating time 4.50: Fuel left: 0.77 kg,
# Simulating time 4.55: Fuel left: 0.77 kg,
# Simulating time 4.60: Fuel left: 0.77 kg,
# Simulating time 4.65: Fuel left: 0.76 kg,
# Simulating time 4.70: Fuel left: 0.76 kg,
# Simulating time 4.75: Fuel left: 0.76 kg,
# Simulating time 4.80: Fuel left: 0.76 kg,
# Simulating time 4.85: Fuel left: 0.75 kg,
# Simulating time 4.90: Fuel left: 0.75 kg,
# Simulating time 4.95: Fuel left: 0.75 kg,
# Simulating time 5.00: Fuel left: 0.74 kg,
# Simulating time 5.05: Fuel left: 0.74 kg,
# Simulating time 5.10: Fuel left: 0.74 kg,
# Simulating time 5.15: Fuel left: 0.73 kg,
# Simulating time 5.20: Fuel left: 0.73 kg,
# Simulating time 5.25: Fuel left: 0.73 kg,
# Simulating time 5.30: Fuel left: 0.73 kg,
# Simulating time 5.35: Fuel left: 0.72 kg,
# Simulating time 5.40: Fuel left: 0.72 kg,
# Simulating time 5.45: Fuel left: 0.72 kg,
# Simulating time 5.50: Fuel left: 0.71 kg,
# Simulating time 5.55: Fuel left: 0.71 kg,
# Simulating time 5.60: Fuel left: 0.71 kg,
# Simulating time 5.65: Fuel left: 0.71 kg,
# Simulating time 5.70: Fuel left: 0.70 kg,
# Simulating time 5.75: Fuel left: 0.70 kg,
# Simulating time 5.80: Fuel left: 0.70 kg,
# Simulating time 5.85: Fuel left: 0.69 kg,
# Simulating time 5.90: Fuel left: 0.69 kg,
# Simulating time 5.95: Fuel left: 0.69 kg,
# Simulating time 6.00: Fuel left: 0.69 kg,
# Simulating time 6.05: Fuel left: 0.68 kg,
# Simulating time 6.10: Fuel left: 0.68 kg,
# Simulating time 6.15: Fuel left: 0.68 kg,
# Simulating time 6.20: Fuel left: 0.68 kg,
# Simulating time 6.25: Fuel left: 0.67 kg,
# Simulating time 6.30: Fuel left: 0.67 kg,
# Simulating time 6.35: Fuel left: 0.67 kg,
# Simulating time 6.40: Fuel left: 0.66 kg,
# Simulating time 6.45: Fuel left: 0.66 kg,
# Simulating time 6.50: Fuel left: 0.66 kg,
# Simulating time 6.55: Fuel left: 0.66 kg,
# Simulating time 6.60: Fuel left: 0.65 kg,
# Simulating time 6.65: Fuel left: 0.65 kg,
# Simulating time 6.70: Fuel left: 0.65 kg,
# Simulating time 6.75: Fuel left: 0.64 kg,
# Simulating time 6.80: Fuel left: 0.64 kg,
# Simulating time 6.85: Fuel left: 0.64 kg,
# Simulating time 6.90: Fuel left: 0.64 kg,
# Simulating time 6.95: Fuel left: 0.63 kg,
# Simulating time 7.00: Fuel left: 0.63 kg,
# Simulating time 7.05: Fuel left: 0.63 kg,
# Simulating time 7.10: Fuel left: 0.63 kg,
# Simulating time 7.15: Fuel left: 0.62 kg,
# Simulating time 7.20: Fuel left: 0.62 kg,
# Simulating time 7.25: Fuel left: 0.62 kg,
# Simulating time 7.30: Fuel left: 0.61 kg,
# Simulating time 7.35: Fuel left: 0.61 kg,
# Simulating time 7.40: Fuel left: 0.61 kg,
# Simulating time 7.45: Fuel left: 0.61 kg,
# Simulating time 7.50: Fuel left: 0.60 kg,
# Simulating time 7.55: Fuel left: 0.60 kg,
# Simulating time 7.60: Fuel left: 0.60 kg,
# Simulating time 7.65: Fuel left: 0.60 kg,
# Simulating time 7.70: Fuel left: 0.59 kg,
# Simulating time 7.75: Fuel left: 0.59 kg,
# Simulating time 7.80: Fuel left: 0.59 kg,
# Simulating time 7.85: Fuel left: 0.59 kg,
# Simulating time 7.90: Fuel left: 0.58 kg,
# Simulating time 7.95: Fuel left: 0.58 kg,
# Simulating time 8.00: Fuel left: 0.58 kg,
# Simulating time 8.05: Fuel left: 0.58 kg,
# Simulating time 8.10: Fuel left: 0.57 kg,
# Simulating time 8.15: Fuel left: 0.57 kg,
# Simulating time 8.20: Fuel left: 0.57 kg,
# Simulating time 8.25: Fuel left: 0.56 kg,
# Simulating time 8.30: Fuel left: 0.56 kg,
# Simulating time 8.35: Fuel left: 0.56 kg,
# Simulating time 8.40: Fuel left: 0.56 kg,
# Simulating time 8.45: Fuel left: 0.55 kg,
# Simulating time 8.50: Fuel left: 0.55 kg,
# Simulating time 8.55: Fuel left: 0.55 kg,
# Simulating time 8.60: Fuel left: 0.55 kg,
# Simulating time 8.65: Fuel left: 0.54 kg,
# Simulating time 8.70: Fuel left: 0.54 kg,
# Simulating time 8.75: Fuel left: 0.54 kg,
# Simulating time 8.80: Fuel left: 0.54 kg,
# Simulating time 8.85: Fuel left: 0.53 kg,
# Simulating time 8.90: Fuel left: 0.53 kg,
# Simulating time 8.95: Fuel left: 0.53 kg,
# Simulating time 9.00: Fuel left: 0.53 kg,
# Simulating time 9.05: Fuel left: 0.52 kg,
# Simulating time 9.10: Fuel left: 0.52 kg,
# Simulating time 9.15: Fuel left: 0.52 kg,
# Simulating time 9.20: Fuel left: 0.52 kg,
# Simulating time 9.25: Fuel left: 0.51 kg,
# Simulating time 9.30: Fuel left: 0.51 kg,
# Simulating time 9.35: Fuel left: 0.51 kg,
# Simulating time 9.40: Fuel left: 0.51 kg,
# Simulating time 9.45: Fuel left: 0.50 kg,
# Simulating time 9.50: Fuel left: 0.50 kg,
# Simulating time 9.55: Fuel left: 0.50 kg,
# Simulating time 9.60: Fuel left: 0.50 kg,
# Simulating time 9.65: Fuel left: 0.49 kg,
# Simulating time 9.70: Fuel left: 0.49 kg,
# Simulating time 9.75: Fuel left: 0.49 kg,
# Simulating time 9.80: Fuel left: 0.49 kg,
# Simulating time 9.85: Fuel left: 0.48 kg,
# Simulating time 9.90: Fuel left: 0.48 kg,
# Simulating time 9.95: Fuel left: 0.48 kg,
# Simulating time 10.00: Fuel left: 0.48 kg,
# Simulating time 10.05: Fuel left: 0.47 kg,
# Simulating time 10.10: Fuel left: 0.47 kg,
# Simulating time 10.15: Fuel left: 0.47 kg,
# Simulating time 10.20: Fuel left: 0.47 kg,
# Simulating time 10.25: Fuel left: 0.46 kg,
# Simulating time 10.30: Fuel left: 0.46 kg,
# Simulating time 10.35: Fuel left: 0.46 kg,
# Simulating time 10.40: Fuel left: 0.46 kg,
# Simulating time 10.45: Fuel left: 0.45 kg,
# Simulating time 10.50: Fuel left: 0.45 kg,
# Simulating time 10.55: Fuel left: 0.45 kg,
# Simulating time 10.60: Fuel left: 0.45 kg,
# Simulating time 10.65: Fuel left: 0.44 kg,
# Simulating time 10.70: Fuel left: 0.44 kg,
# Simulating time 10.75: Fuel left: 0.44 kg,
# Simulating time 10.80: Fuel left: 0.44 kg,
# Simulating time 10.85: Fuel left: 0.43 kg,
# Simulating time 10.90: Fuel left: 0.43 kg,
# Simulating time 10.95: Fuel left: 0.43 kg,
# Simulating time 11.00: Fuel left: 0.43 kg,
# Simulating time 11.05: Fuel left: 0.43 kg,
# Simulating time 11.10: Fuel left: 0.42 kg,
# Simulating time 11.15: Fuel left: 0.42 kg,
# Simulating time 11.20: Fuel left: 0.42 kg,
# Simulating time 11.25: Fuel left: 0.42 kg,
# Simulating time 11.30: Fuel left: 0.41 kg,
# Simulating time 11.35: Fuel left: 0.41 kg,
# Simulating time 11.40: Fuel left: 0.41 kg,
# Simulating time 11.45: Fuel left: 0.41 kg,
# Simulating time 11.50: Fuel left: 0.40 kg,
# Simulating time 11.55: Fuel left: 0.40 kg,
# Simulating time 11.60: Fuel left: 0.40 kg,
# Simulating time 11.65: Fuel left: 0.40 kg,
# Simulating time 11.70: Fuel left: 0.39 kg,
# Simulating time 11.75: Fuel left: 0.39 kg,
# Simulating time 11.80: Fuel left: 0.39 kg,
# Simulating time 11.85: Fuel left: 0.39 kg,
# Simulating time 11.90: Fuel left: 0.39 kg,
# Simulating time 11.95: Fuel left: 0.38 kg,
# Simulating time 12.00: Fuel left: 0.38 kg,
# Simulating time 12.05: Fuel left: 0.38 kg,
# Simulating time 12.10: Fuel left: 0.38 kg,
# Simulating time 12.15: Fuel left: 0.37 kg,
# Simulating time 12.20: Fuel left: 0.37 kg,
# Simulating time 12.25: Fuel left: 0.37 kg,
# Simulating time 12.30: Fuel left: 0.37 kg,
# Simulating time 12.35: Fuel left: 0.36 kg,
# Simulating time 12.40: Fuel left: 0.36 kg,
# Simulating time 12.45: Fuel left: 0.36 kg,
# Simulating time 12.50: Fuel left: 0.36 kg,
# Simulating time 12.55: Fuel left: 0.36 kg,
# Simulating time 12.60: Fuel left: 0.35 kg,
# Simulating time 12.65: Fuel left: 0.35 kg,
# Simulating time 12.70: Fuel left: 0.35 kg,
# Simulating time 12.75: Fuel left: 0.35 kg,
# Simulating time 12.80: Fuel left: 0.34 kg,
# Simulating time 12.85: Fuel left: 0.34 kg,
# Simulating time 12.90: Fuel left: 0.34 kg,
# Simulating time 12.95: Fuel left: 0.34 kg,
# Simulating time 13.00: Fuel left: 0.34 kg,
# Simulating time 13.05: Fuel left: 0.33 kg,
# Simulating time 13.10: Fuel left: 0.33 kg,
# Simulating time 13.15: Fuel left: 0.33 kg,
# Simulating time 13.20: Fuel left: 0.33 kg,
# Simulating time 13.25: Fuel left: 0.32 kg,
# Simulating time 13.30: Fuel left: 0.32 kg,
# Simulating time 13.35: Fuel left: 0.32 kg,
# Simulating time 13.40: Fuel left: 0.32 kg,
# Simulating time 13.45: Fuel left: 0.32 kg,
# Simulating time 13.50: Fuel left: 0.31 kg,
# Simulating time 13.55: Fuel left: 0.31 kg,
# Simulating time 13.60: Fuel left: 0.31 kg,
# Simulating time 13.65: Fuel left: 0.31 kg,
# Simulating time 13.70: Fuel left: 0.30 kg,
# Simulating time 13.75: Fuel left: 0.30 kg,
# Simulating time 13.80: Fuel left: 0.30 kg,
# Simulating time 13.85: Fuel left: 0.30 kg,
# Simulating time 13.90: Fuel left: 0.30 kg,
# Simulating time 13.95: Fuel left: 0.29 kg,
# Simulating time 14.00: Fuel left: 0.29 kg,
# Simulating time 14.05: Fuel left: 0.29 kg,
# Simulating time 14.10: Fuel left: 0.29 kg,
# Simulating time 14.15: Fuel left: 0.29 kg,
# Simulating time 14.20: Fuel left: 0.28 kg,
# Simulating time 14.25: Fuel left: 0.28 kg,
# Simulating time 14.30: Fuel left: 0.28 kg,
# Simulating time 14.35: Fuel left: 0.28 kg,
# Simulating time 14.40: Fuel left: 0.27 kg,
# Simulating time 14.45: Fuel left: 0.27 kg,
# Simulating time 14.50: Fuel left: 0.27 kg,
# Simulating time 14.55: Fuel left: 0.27 kg,
# Simulating time 14.60: Fuel left: 0.27 kg,
# Simulating time 14.65: Fuel left: 0.26 kg,
# Simulating time 14.70: Fuel left: 0.26 kg,
# Simulating time 14.75: Fuel left: 0.26 kg,
# Simulating time 14.80: Fuel left: 0.26 kg,
# Simulating time 14.85: Fuel left: 0.26 kg,
# Simulating time 14.90: Fuel left: 0.25 kg,
# Simulating time 14.95: Fuel left: 0.25 kg,
# Simulating time 15.00: Fuel left: 0.25 kg,
# Simulating time 15.05: Fuel left: 0.25 kg,
# Simulating time 15.10: Fuel left: 0.25 kg,
# Simulating time 15.15: Fuel left: 0.24 kg,
# Simulating time 15.20: Fuel left: 0.24 kg,
# Simulating time 15.25: Fuel left: 0.24 kg,
# Simulating time 15.30: Fuel left: 0.24 kg,
# Simulating time 15.35: Fuel left: 0.24 kg,
# Simulating time 15.40: Fuel left: 0.23 kg,
# Simulating time 15.45: Fuel left: 0.23 kg,
# Simulating time 15.50: Fuel left: 0.23 kg,
# Simulating time 15.55: Fuel left: 0.23 kg,
# Simulating time 15.60: Fuel left: 0.22 kg,
# Simulating time 15.65: Fuel left: 0.22 kg,
# Simulating time 15.70: Fuel left: 0.22 kg,
# Simulating time 15.75: Fuel left: 0.22 kg,
# Simulating time 15.80: Fuel left: 0.22 kg,
# Simulating time 15.85: Fuel left: 0.21 kg,
# Simulating time 15.90: Fuel left: 0.21 kg,
# Simulating time 15.95: Fuel left: 0.21 kg,
# Simulating time 16.00: Fuel left: 0.21 kg,
# Simulating time 16.05: Fuel left: 0.21 kg,
# Simulating time 16.10: Fuel left: 0.20 kg,
# Simulating time 16.15: Fuel left: 0.20 kg,
# Simulating time 16.20: Fuel left: 0.20 kg,
# Simulating time 16.25: Fuel left: 0.20 kg,
# Simulating time 16.30: Fuel left: 0.20 kg,
# Simulating time 16.35: Fuel left: 0.19 kg,
# Simulating time 16.40: Fuel left: 0.19 kg,
# Simulating time 16.45: Fuel left: 0.19 kg,
# Simulating time 16.50: Fuel left: 0.19 kg,
# Simulating time 16.55: Fuel left: 0.19 kg,
# Simulating time 16.60: Fuel left: 0.18 kg,
# Simulating time 16.65: Fuel left: 0.18 kg,
# Simulating time 16.70: Fuel left: 0.18 kg,
# Simulating time 16.75: Fuel left: 0.18 kg,
# Simulating time 16.80: Fuel left: 0.18 kg,
# Simulating time 16.85: Fuel left: 0.17 kg,
# Simulating time 16.90: Fuel left: 0.17 kg,
# Simulating time 16.95: Fuel left: 0.17 kg,
# Simulating time 17.00: Fuel left: 0.17 kg,
# Simulating time 17.05: Fuel left: 0.17 kg,
# Simulating time 17.10: Fuel left: 0.16 kg,
# Simulating time 17.15: Fuel left: 0.16 kg,
# Simulating time 17.20: Fuel left: 0.16 kg,
# Simulating time 17.25: Fuel left: 0.16 kg,
# Simulating time 17.30: Fuel left: 0.16 kg,
# Simulating time 17.35: Fuel left: 0.15 kg,
# Simulating time 17.40: Fuel left: 0.15 kg,
# Simulating time 17.45: Fuel left: 0.15 kg,
# Simulating time 17.50: Fuel left: 0.15 kg,
# Simulating time 17.55: Fuel left: 0.15 kg,
# Simulating time 17.60: Fuel left: 0.14 kg,
# Simulating time 17.65: Fuel left: 0.14 kg,
# Simulating time 17.70: Fuel left: 0.14 kg,
# Simulating time 17.75: Fuel left: 0.14 kg,
# Simulating time 17.80: Fuel left: 0.14 kg,
# Simulating time 17.85: Fuel left: 0.13 kg,
# Simulating time 17.90: Fuel left: 0.13 kg,
# Simulating time 17.95: Fuel left: 0.13 kg,
# Simulating time 18.00: Fuel left: 0.13 kg,
# Simulating time 18.05: Fuel left: 0.13 kg,
# Simulating time 18.10: Fuel left: 0.12 kg,
# Simulating time 18.15: Fuel left: 0.12 kg,
# Simulating time 18.20: Fuel left: 0.12 kg,
# Simulating time 18.25: Fuel left: 0.12 kg,
# Simulating time 18.30: Fuel left: 0.12 kg,
# Simulating time 18.35: Fuel left: 0.11 kg,
# Simulating time 18.40: Fuel left: 0.11 kg,
# Simulating time 18.45: Fuel left: 0.11 kg,
# Simulating time 18.50: Fuel left: 0.11 kg,
# Simulating time 18.55: Fuel left: 0.11 kg,
# Simulating time 18.60: Fuel left: 0.10 kg,
# Simulating time 18.65: Fuel left: 0.10 kg,
# Simulating time 18.70: Fuel left: 0.10 kg,
# Simulating time 18.75: Fuel left: 0.10 kg,
# Simulating time 18.80: Fuel left: 0.10 kg,
# Simulating time 18.85: Fuel left: 0.09 kg,
# Simulating time 18.90: Fuel left: 0.09 kg,
# Simulating time 18.95: Fuel left: 0.09 kg,
# Simulating time 19.00: Fuel left: 0.09 kg,
# Simulating time 19.05: Fuel left: 0.09 kg,
# Simulating time 19.10: Fuel left: 0.08 kg,
# Simulating time 19.15: Fuel left: 0.08 kg,
# Simulating time 19.20: Fuel left: 0.08 kg,
# Simulating time 19.25: Fuel left: 0.08 kg,
# Simulating time 19.30: Fuel left: 0.08 kg,
# Simulating time 19.35: Fuel left: 0.07 kg,
# Simulating time 19.40: Fuel left: 0.07 kg,
# Simulating time 19.45: Fuel left: 0.07 kg,
# Simulating time 19.50: Fuel left: 0.07 kg,
# Simulating time 19.55: Fuel left: 0.07 kg,
# Simulating time 19.60: Fuel left: 0.06 kg,
# Simulating time 19.65: Fuel left: 0.06 kg,
# Simulating time 19.70: Fuel left: 0.06 kg,
# Simulating time 19.75: Fuel left: 0.06 kg,
# Simulating time 19.80: Fuel left: 0.06 kg,
# Simulating time 19.85: Fuel left: 0.05 kg,
# Simulating time 19.90: Fuel left: 0.05 kg,
# Simulating time 19.95: Fuel left: 0.05 kg,

# %%
vis = RocketVis(rocket, rocket_obj_path)
vis.anim_rate = 1.0
vis.animate(t_cl[:-1], x_cl[:,:-1], u_cl, Ref=ref[:,:-1], T_ol=t_ol[...,:-1], X_ol=x_ol, U_ol=u_ol);
# Out:
# Exception in callback Task.__step()
# handle: <Handle Task.__step()>
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: cannot enter context: <_contextvars.Context object at 0x000001B4963D7040> is already entered
# Exception in callback Task.__step()
# handle: <Handle Task.__step()>
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: cannot enter context: <_contextvars.Context object at 0x000001B4963D7040> is already entered
# Exception in callback Task.__step()
# handle: <Handle Task.__step()>
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: cannot enter context: <_contextvars.Context object at 0x000001B4963D7040> is already entered
# Exception in callback Task.__step()
# handle: <Handle Task.__step()>
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: cannot enter context: <_contextvars.Context object at 0x000001B4963D7040> is already entered
# Exception in callback Task.__step()
# handle: <Handle Task.__step()>
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: cannot enter context: <_contextvars.Context object at 0x000001B4963D7040> is already entered
# Task was destroyed but it is pending!
# task: <Task pending name='Task-3' coro=<_async_in_context.<locals>.run_in_context() done, defined at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\ipykernel\utils.py:57> wait_for=<Task pending name='Task-5' coro=<Kernel.shell_main() running at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\ipykernel\kernelbase.py:590> cb=[Task.__wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\zmq\eventloop\zmqstream.py:563]>
# c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\trame_client\widgets\core.py:847: RuntimeWarning: coroutine 'Kernel.shell_main' was never awaited
#   self._attr_names.append((f"v_slot_{safe_name}", f"v-slot:{slot_name}"))
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Task was destroyed but it is pending!
# task: <Task pending name='Task-5' coro=<Kernel.shell_main() running at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\ipykernel\kernelbase.py:590> cb=[Task.__wakeup()]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-6' coro=<_async_in_context.<locals>.run_in_context() done, defined at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\ipykernel\utils.py:57> wait_for=<Task pending name='Task-7' coro=<Kernel.shell_main() running at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\ipykernel\kernelbase.py:590> cb=[Task.__wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\zmq\eventloop\zmqstream.py:563]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-7' coro=<Kernel.shell_main() running at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\ipykernel\kernelbase.py:590> cb=[Task.__wakeup()]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-8' coro=<_async_in_context.<locals>.run_in_context() done, defined at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\ipykernel\utils.py:57> wait_for=<Task pending name='Task-9' coro=<Kernel.shell_main() running at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\ipykernel\kernelbase.py:590> cb=[Task.__wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\zmq\eventloop\zmqstream.py:563]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-9' coro=<Kernel.shell_main() running at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\ipykernel\kernelbase.py:590> cb=[Task.__wakeup()]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-10' coro=<_async_in_context.<locals>.run_in_context() done, defined at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\ipykernel\utils.py:57> wait_for=<Task pending name='Task-11' coro=<Kernel.shell_main() running at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\ipykernel\kernelbase.py:590> cb=[Task.__wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\zmq\eventloop\zmqstream.py:563]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-11' coro=<Kernel.shell_main() running at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\ipykernel\kernelbase.py:590> cb=[Task.__wakeup()]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-12' coro=<_async_in_context.<locals>.run_in_context() done, defined at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\ipykernel\utils.py:57> wait_for=<Task pending name='Task-13' coro=<Kernel.shell_main() running at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\ipykernel\kernelbase.py:590> cb=[Task.__wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\zmq\eventloop\zmqstream.py:563]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-13' coro=<Kernel.shell_main() running at c:\Users\killi\Desktop\MPC-Course-EPFL\.env\Lib\site-packages\ipykernel\kernelbase.py:590> cb=[Task.__wakeup()]>
# AppLayout(children=(HBox(children=(Play(value=0, description='Press play', max=399, step=2), IntSlider(value=0…

# %%
from matplotlib import pyplot as plt
plot_static_states_inputs(t_cl[:-1], x_cl[:,:-1], u_cl, ref[:,:-1])
plt.savefig('variable-disturbance-part5')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
